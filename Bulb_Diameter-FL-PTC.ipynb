# %%
# Use seaborn for pairplot.
# !pip install -q seaborn

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# Make NumPy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2.8.0

# %% [markdown]
# ### Get the data
# First import the dataset using pandas:

# %%
#raw_dataset = pd.read_csv('G_datasets-AEA.csv')

# %%
raw_dataset = pd.read_csv('FL_G_dataset-PTC.csv')

# %%
dataset = raw_dataset.copy()
dataset.tail()
# Out:
#     DAT(days)  Temp     WC     NL  N(PTC) (mg/g)  P(PTC) (mg/g)  \
# 86         89  29.5  16.29  12.71          35.76           7.10
# 87         90  27.9  16.32  12.78          35.61           7.11
# 88         91  27.1  16.39  12.82          35.55           7.12
# 89         92  26.1  16.44  12.85          35.19           7.13
# 90         93  26.9  16.50  12.88          34.45           7.14
#
#     K(PTC) (mg/g)  Ca(PTC) (mg/g)  Mg(PTC) (mg/g)  S(PTC) (mg/g)  \
# 86          49.88           10.47            1.58           3.21
# 87          49.76           10.48            1.59           3.22
# 88          48.53           10.49            1.60           3.23
# 89          48.31           10.50            1.61           3.24
# 90          48.02           10.51            1.62           3.25
#
#     Na(PTC) (mg/g)  Diameter of Bulb(mm)
# 86            1.08                 24.95
# 87            1.07                 25.64
# 88            1.06                 27.83
# 89            1.05                 28.24
# 90            1.04                 33.88

# %% [markdown]
# ### Clean the data
#
# The dataset contains a few unknown values:

# %%
dataset.isna().sum()
# Out:
# DAT(days)               0
# Temp                    0
# WC                      0
# NL                      0
# N(PTC) (mg/g)           0
# P(PTC) (mg/g)           0
# K(PTC) (mg/g)           0
# Ca(PTC) (mg/g)          0
# Mg(PTC) (mg/g)          0
# S(PTC) (mg/g)           0
# Na(PTC) (mg/g)          0
# Diameter of Bulb(mm)    0
# dtype: int64

# %% [markdown]
# Drop those rows to keep this initial tutorial simple:

# %%
dataset = dataset.dropna()

# %% [markdown]
# ### Split the data into training and test sets
#
# Now, split the dataset into a training set and a test set. You will use the test set in the final evaluation of your models.

# %%
train_dataset = dataset.sample(frac=0.8, random_state=0)
test_dataset = dataset.drop(train_dataset.index)

# %% [markdown]
# ### Inspect the data
#
# Review the joint distribution of a few pairs of columns from the training set.
#
# The top row suggests that the Temperature is a function of all the other parameters. The other rows indicate they are functions of each other.

# %%
#sns.pairplot(train_dataset[['MPG', 'Cylinders', 'Displacement', 'Weight']], diag_kind='kde')
sns.pairplot(train_dataset[['DAT(days)','Temp','WC','NL','N(PTC) (mg/g)','P(PTC) (mg/g)','K(PTC) (mg/g)','Ca(PTC) (mg/g)','Mg(PTC) (mg/g)','S(PTC) (mg/g)','Na(PTC) (mg/g)','Diameter of Bulb(mm)']]
             ,diag_kind='kde')

# %% [markdown]
# Let's also check the overall statistics. Note how each feature covers a very different range:

# %%
train_dataset.describe().transpose()
# Out:
#                       count        mean         std    min    25%    50%  \
# DAT(days)              73.0   46.630137   27.651355   1.00  22.00  46.00
# Temp                   73.0   21.753425    3.487481  13.90  18.90  21.50
# WC                     73.0    6.192740    4.945820   0.11   2.46   5.18
# NL                     73.0    9.919863    1.868095   6.88   8.16   9.88
# N(PTC) (mg/g)          73.0   46.129589    8.940449  33.55  38.29  43.78
# P(PTC) (mg/g)          73.0    6.442192    0.521859   4.91   6.21   6.59
# K(PTC) (mg/g)          73.0  168.766027  912.185009  37.29  53.91  59.64
# Ca(PTC) (mg/g)         73.0   19.455890   83.858944   7.25   7.52  10.40
# Mg(PTC) (mg/g)         73.0    1.649726    0.404406   1.00   1.32   1.56
# S(PTC) (mg/g)          73.0    2.759178    0.522919   1.93   2.25   3.06
# Na(PTC) (mg/g)         73.0    1.275890    0.339554   0.11   1.32   1.39
# Diameter of Bulb(mm)   73.0   20.796712    2.773102  17.62  18.59  20.31
#
#                         75%      max
# DAT(days)             71.00    93.00
# Temp                  25.00    29.50
# WC                     8.36    16.50
# NL                    11.57    12.88
# N(PTC) (mg/g)         53.04    64.35
# P(PTC) (mg/g)          6.83     7.14
# K(PTC) (mg/g)         75.20  7855.00
# Ca(PTC) (mg/g)        11.25   726.00
# Mg(PTC) (mg/g)         2.10     2.22
# S(PTC) (mg/g)          3.23     3.39
# Na(PTC) (mg/g)         1.46     1.57
# Diameter of Bulb(mm)  22.23    33.88

# %% [markdown]
# ### Split features from labels
#
# Separate the target value—the "label"—from the features. This label is the value that you will train the model to predict.

# %%
train_features = train_dataset.copy()
test_features = test_dataset.copy()

train_labels = train_features.pop('Diameter of Bulb(mm)')
test_labels = test_features.pop('Diameter of Bulb(mm)')

# %% [markdown]
# ## Normalization
#
# In the table of statistics it's easy to see how different the ranges of each feature are:

# %%
train_dataset.describe().transpose()[['mean', 'std']]
# Out:
#                             mean         std
# DAT(days)              46.630137   27.651355
# Temp                   21.753425    3.487481
# WC                      6.192740    4.945820
# NL                      9.919863    1.868095
# N(PTC) (mg/g)          46.129589    8.940449
# P(PTC) (mg/g)           6.442192    0.521859
# K(PTC) (mg/g)         168.766027  912.185009
# Ca(PTC) (mg/g)         19.455890   83.858944
# Mg(PTC) (mg/g)          1.649726    0.404406
# S(PTC) (mg/g)           2.759178    0.522919
# Na(PTC) (mg/g)          1.275890    0.339554
# Diameter of Bulb(mm)   20.796712    2.773102

# %% [markdown]
# It is good practice to normalize features that use different scales and ranges.
#
# One reason this is important is because the features are multiplied by the model weights. So, the scale of the outputs and the scale of the gradients are affected by the scale of the inputs.
#
# normalization makes training much more stable.

# %% [markdown]
# ### The Normalization layer
#
# The `tf.keras.layers.Normalization` is a clean and simple way to add feature normalization into your model.
#
# The first step is to create the layer:

# %%
normalizer = tf.keras.layers.Normalization(axis=-1)

# %% [markdown]
# Then, fit the state of the preprocessing layer to the data by calling `Normalization.adapt`:

# %%
normalizer.adapt(np.array(train_features))

# %% [markdown]
# Calculate the mean and variance, and store them in the layer:

# %%
print(normalizer.mean.numpy())
# Out:
# [[ 46.63   21.753   6.193   9.92   46.13    6.442 168.766  19.456   1.65
#     2.759   1.276]]

# %% [markdown]
# When the layer is called, it returns the input data, with each feature independently normalized:

# %%
first = np.array(train_features[:1])

with np.printoptions(precision=2, suppress=True):
  print('First example:', first)
  print()
  print('Normalized:', normalizer(first).numpy())
# Out:
# First example: [[ 3.   18.3   0.13  7.   35.63  5.12 39.41  7.27  2.16  1.95  0.79]]
#
# Normalized: [[-1.59 -1.   -1.23 -1.57 -1.18 -2.55 -0.14 -0.15  1.27 -1.56 -1.44]]

# %% [markdown]
# ## Linear regression
#
# Before building a deep neural network model, start with linear regression using one and several variables.

# %% [markdown]
# ### Linear regression with one variable
#
# Begin with a single-variable linear regression to predict 'Diameter of Bulb' from 'Number of Leaves(NL)'.
#
# There are two steps in your single-variable linear regression model:
#
# - Normalize the `'NL'` input features using the `tf.keras.layers.Normalization` preprocessing layer.
# - Apply a linear transformation ($y = mx+b$) to produce 1 output using a linear layer (`tf.keras.layers.Dense`).
#
# The number of _inputs_ can either be set by the `input_shape` argument, or automatically when the model is run for the first time.

# %% [markdown]
# First, create a NumPy array made of the `'NL'` features. Then, instantiate the `tf.keras.layers.Normalization` and fit its state to the `NL` data:

# %%
NL = np.array(train_features['NL'])

NL_normalizer = layers.Normalization(input_shape=[1,], axis=None)
NL_normalizer.adapt(NL)

# %% [markdown]
# Build the Keras Sequential model:

# %%
NL_model = tf.keras.Sequential([
    NL_normalizer,
    layers.Dense(units=1)
])

NL_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization_1 (Normalizat  (None, 1)                3
#  ion)
#
#  dense (Dense)               (None, 1)                 2
#
# =================================================================
# Total params: 5
# Trainable params: 2
# Non-trainable params: 3
# _________________________________________________________________

# %% [markdown]
# This model will predict `'Diameter of Bulb'` from `'NL'`.
#
# Run the untrained model on the first 10 'Horsepower' values. The output won't be good, but notice that it has the expected shape of `(10, 1)`:

# %%
NL_model.predict(NL[:5])
# Out:
# array([[-0.014],
#        [-0.011],
#        [ 0.003],
#        [-0.001],
#        [ 0.014]], dtype=float32)

# %% [markdown]
# Once the model is built, configure the training procedure using the Keras `Model.compile` method. The most important arguments to compile are the `loss` and the `optimizer`, since these define what will be optimized (`mean_absolute_error`) and how (using the `tf.keras.optimizers.Adam`).

# %%
NL_model.compile(
    optimizer=tf.optimizers.Adam(learning_rate=0.1),
    loss='mean_absolute_error')

# %% [markdown]
# Use Keras `Model.fit` to execute the training for 100 epochs:

# %%
# %%time
history = NL_model.fit(
    train_features['NL'],
    train_labels,
    epochs=100,
    # Suppress logging.
    verbose=0,
    # Calculate validation results on 20% of the training data.
    validation_split = 0.2)
# Out:
# Wall time: 3.3 s

# %% [markdown]
# Visualize the model's training progress using the stats stored in the `history` object:

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#         loss  val_loss  epoch
# 95  2.208532  3.168776     95
# 96  2.024953  2.932588     96
# 97  1.845750  2.693947     97
# 98  1.674015  2.459907     98
# 99  1.491896  2.232823     99

# %%
def plot_loss(history):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  plt.ylim([0, 300])
  plt.xlabel('Epoch')
  plt.ylabel('Error [Diameter of Bulb(mm)]')
  plt.legend()
  plt.grid(True)

# %%
plot_loss(history)

# %% [markdown]
# Collect the results on the test set for later:

# %%
test_results = {}

test_results['NL_model'] = NL_model.evaluate(
    test_features['NL'],
    test_labels, verbose=0)

# %% [markdown]
# Since this is a single variable regression, it's easy to view the model's predictions as a function of the input:

# %%
x = tf.linspace(0.0, 12, 12)
y = NL_model.predict(x)

# %%
def plot_NL(x, y):
  plt.scatter(train_features['NL'], train_labels, label='Data')
  plt.plot(x, y, color='k', label='Predictions')
  plt.xlabel('NL')
  plt.ylabel('Diameter of Bulb(mm)')
  plt.legend()

# %%
plot_NL(x, y)

# %% [markdown]
# ### Linear regression with multiple inputs

# %% [markdown]
# You can use an almost identical setup to make predictions based on multiple inputs. This model still does the same $y = mx+b$ except that $m$ is a matrix and $b$ is a vector.
#
# Create a two-step Keras Sequential model again with the first layer being `normalizer` (`tf.keras.layers.Normalization(axis=-1)`) you defined earlier and adapted to the whole dataset:

# %%
linear_model = tf.keras.Sequential([
    normalizer,
    layers.Dense(units=1)
])

# %% [markdown]
# When you call `Model.predict` on a batch of inputs, it produces `units=1` outputs for each example:

# %%
linear_model.predict(train_features[:6])
# Out:
# array([[ 1.411],
#        [ 1.754],
#        [-1.307],
#        [-1.362],
#        [-0.906],
#        [ 0.037]], dtype=float32)

# %% [markdown]
# When you call the model, its weight matrices will be built—check that the `kernel` weights (the $m$ in $y=mx+b$) have a shape of `(9, 1)`:

# %%
linear_model.layers[1].kernel
# Out:
# <tf.Variable 'dense_1/kernel:0' shape=(11, 1) dtype=float32, numpy=
# array([[-0.056],
#        [-0.684],
#        [ 0.674],
#        [-0.627],
#        [-0.107],
#        [ 0.175],
#        [-0.602],
#        [ 0.373],
#        [ 0.676],
#        [ 0.022],
#        [ 0.035]], dtype=float32)>

# %% [markdown]
# Configure the model with Keras `Model.compile` and train with `Model.fit` for 100 epochs:

# %%
linear_model.compile(
    optimizer=tf.optimizers.Adam(learning_rate=0.1),
    loss='mean_absolute_error')

# %%
# %%time
history = linear_model.fit(
    train_features,
    train_labels,
    epochs=100,
    # Suppress logging.
    verbose=0,
    # Calculate validation results on 20% of the training data.
    validation_split = 0.2)
# Out:
# Wall time: 2.93 s

# %% [markdown]
# Using all the inputs in this regression model achieves a much lower training and validation error than the `NL`, which had one input:

# %%
plot_loss(history)

# %% [markdown]
# Collect the results on the test set for later:

# %%
test_results['linear_model'] = linear_model.evaluate(
    test_features, test_labels, verbose=0)

# %% [markdown]
# ## Regression with a deep neural network (DNN)

# %% [markdown]
# In the previous section, you implemented two linear models for single and multiple inputs.
#
# Here, you will implement single-input and multiple-input DNN models.
#
# The code is basically the same except the model is expanded to include some "hidden" non-linear layers. The name "hidden" here just means not directly connected to the inputs or outputs.

# %% [markdown]
# These models will contain a few more layers than the linear model:
#
# * The normalization layer, as before (with `NL_normalizer` for a single-input model and `normalizer` for a multiple-input model).
# * Two hidden, non-linear, `Dense` layers with the ReLU (`relu`) activation function nonlinearity.
# * A linear `Dense` single-output layer.
#
# Both models will use the same training procedure so the `compile` method is included in the `build_and_compile_model` function below.

# %%
def build_and_compile_model(norm):
  model = keras.Sequential([
      norm,
      layers.Dense(24, activation='relu'),
      layers.Dense(24, activation='relu'),
      layers.Dense(1)
  ])

  model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.01))
  return model

# %% [markdown]
# ### Regression using a DNN and a single input

# %% [markdown]
# Create a DNN model with only `'NL'` as input and `NL_normalizer` (defined earlier) as the normalization layer:

# %%
dnn_NL_model = build_and_compile_model(NL_normalizer)

# %% [markdown]
# This model has quite a few more trainable parameters than the linear models:

# %%
dnn_NL_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization_1 (Normalizat  (None, 1)                3
#  ion)
#
#  dense_2 (Dense)             (None, 24)                48
#
#  dense_3 (Dense)             (None, 24)                600
#
#  dense_4 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 676
# Trainable params: 673
# Non-trainable params: 3
# _________________________________________________________________

# %% [markdown]
# Train the model with Keras `Model.fit`:

# %%
# %%time
history = dnn_NL_model.fit(
    train_features['NL'],
    train_labels,
    validation_split=0.2,
    verbose=0, epochs=100)
# Out:
# Wall time: 3.37 s

# %% [markdown]
# This model does slightly better than the linear single-input `NL_model`:

# %%
plot_loss(history)

# %% [markdown]
# If you plot the predictions as a function of `'NL'`, you should notice how this model takes advantage of the nonlinearity provided by the hidden layers:

# %%
x = tf.linspace(0.0, 12, 12)
y = dnn_NL_model.predict(x)

# %%
plot_NL(x, y)

# %% [markdown]
# Collect the results on the test set for later:

# %%
test_results['dnn_NL_model'] = dnn_NL_model.evaluate(
    test_features['NL'], test_labels,
    verbose=0)

# %% [markdown]
# ### Regression using a DNN and multiple inputs

# %% [markdown]
# Repeat the previous process using all the inputs. The model's performance slightly improves on the validation dataset.

# %%
dnn_model = build_and_compile_model(normalizer)
dnn_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizatio  (None, 11)               23
#  n)
#
#  dense_5 (Dense)             (None, 24)                288
#
#  dense_6 (Dense)             (None, 24)                600
#
#  dense_7 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 936
# Trainable params: 913
# Non-trainable params: 23
# _________________________________________________________________

# %%
# %%time
history = dnn_model.fit(
    train_features,
    train_labels,
    validation_split=0.2,
    verbose=0, epochs=100)
# Out:
# Wall time: 4.19 s

# %%
plot_loss(history)

# %% [markdown]
# Collect the results on the test set:

# %%
test_results['dnn_model'] = dnn_model.evaluate(test_features, test_labels, verbose=0)

# %% [markdown]
# ## Performance

# %% [markdown]
# Since all models have been trained, you can review their test set performance:

# %%
pd.DataFrame(test_results, index=['Mean absolute error [Diameter of Bulb(mm)]']).T
# Out:
#               Mean absolute error [Diameter of Bulb(mm)]
# NL_model                                        1.465805
# linear_model                                    8.612428
# dnn_NL_model                                    0.135233
# dnn_model                                       0.472772

# %% [markdown]
# These results match the validation error observed during training.

# %% [markdown]
# ### Make predictions
#
# You can now make predictions with the `dnn_model` on the test set using Keras `Model.predict` and review the loss:

# %%
test_predictions = dnn_model.predict(test_features).flatten()

a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [Diameter of Bulb(mm)]')
plt.ylabel('Predictions [Diameter of Bulb(mm)]')
lims = [0, 30]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001C19E4CAC10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# It appears that the model predicts reasonably well.
#
# Now, check the error distribution:

# %%
error = test_predictions - test_labels
plt.hist(error, bins=5)
plt.xlabel('Prediction Error [Diameter of Bulb(mm)]')
_ = plt.ylabel('Count')

# %% [markdown]
# If you're happy with the model, save it for later use with `Model.save`:

# %%
dnn_model.save('dnn_model')
# Out:
# INFO:tensorflow:Assets written to: dnn_model\assets

# %% [markdown]
# If you reload the model, it gives identical output:

# %%
reloaded = tf.keras.models.load_model('dnn_model')

test_results['reloaded'] = reloaded.evaluate(
    test_features, test_labels, verbose=0)

# %%
(pd.DataFrame(test_results, index=['Mean absolute error [Diameter of Bulb(mm)]']).T)
# Out:
#               Mean absolute error [Diameter of Bulb(mm)]
# NL_model                                        1.465805
# linear_model                                    8.612428
# dnn_NL_model                                    0.135233
# dnn_model                                       0.472772
# reloaded                                        0.472772

# %% [markdown]
# ## Conclusion
#
# This notebook introduced a few techniques to handle a regression problem. Here are a few more tips that may help:
#
# - Mean squared error (MSE) (`tf.keras.losses.MeanSquaredError`) and mean absolute error (MAE) (`tf.keras.losses.MeanAbsoluteError`) are common loss functions used for regression problems. MAE is less sensitive to outliers. Different loss functions are used for classification problems.
# - Similarly, evaluation metrics used for regression differ from classification.
# - When numeric input data features have values with different ranges, each feature should be scaled independently to the same range.
# - Overfitting is a common problem for DNN models, though it wasn't a problem for this tutorial. Visit the [Overfit and underfit](overfit_and_underfit.ipynb) tutorial for more help with this.

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

# %%
df = pd.read_csv('FL_G_dataset-PTC.csv')
x = df.iloc[:,:-1].values
y = df[['Diameter of Bulb(mm)']]
#x = [[0, 1], [5, 1], [15, 2], [25, 5], [35, 11], [45, 15], [55, 34], [60, 35] ]
#y = [4, 5, 20, 14, 32, 22, 38, 43]
x, y = np.array(x), np.array(y)

# %%
x = sm.add_constant(x)

# %%
# Create a model and fit it,The regression model based on ordinary least squares is an instance of the class statsmodels.
#regression.linear_model
model = sm.OLS(y, x)

# %%
# By calling .fit(), you obtain the variable results, which is an instance of the class statsmodels.
# regression.linear_model.RegressionResultsWrapper.
results = model.fit()

# %%
#call .summary() to get the table with the results of linear regression
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.884
# Model:                            OLS   Adj. R-squared:                  0.868
# Method:                 Least Squares   F-statistic:                     54.92
# Date:                Tue, 07 Jun 2022   Prob (F-statistic):           2.26e-32
# Time:                        10:34:48   Log-Likelihood:                -118.21
# No. Observations:                  91   AIC:                             260.4
# Df Residuals:                      79   BIC:                             290.6
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         71.0023     15.254      4.655      0.000      40.640     101.364
# x1             0.5115      0.131      3.914      0.000       0.251       0.772
# x2            -0.0614      0.073     -0.841      0.403      -0.207       0.084
# x3             0.3803      0.101      3.771      0.000       0.180       0.581
# x4            -6.2486      1.718     -3.638      0.000      -9.668      -2.829
# x5             0.0926      0.031      2.972      0.004       0.031       0.155
# x6            -2.5104      1.183     -2.123      0.037      -4.864      -0.157
# x7          -3.14e-05   9.13e-05     -0.344      0.732      -0.000       0.000
# x8             0.0007      0.001      0.467      0.642      -0.002       0.004
# x9             0.1441      0.739      0.195      0.846      -1.326       1.615
# x10            0.1971      0.812      0.243      0.809      -1.419       1.813
# x11           -1.5944      0.478     -3.334      0.001      -2.546      -0.643
# ==============================================================================
# Omnibus:                      125.267   Durbin-Watson:                   0.617
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4396.872
# Skew:                           4.489   Prob(JB):                         0.00
# Kurtosis:                      35.848   Cond. No.                     1.80e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.8e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# To get rsquared, rsquared_adj, param
print(f"coefficient of determination: {results.rsquared}")
print(f"adjusted coefficient of determination: {results.rsquared_adj}")
print(f"regression coefficients: {results.params}")
# Out:
# coefficient of determination: 0.8843634476223909
# adjusted coefficient of determination: 0.8682621555191795
# regression coefficients: [ 7.10022764e+01  5.11524816e-01 -6.14187230e-02  3.80274925e-01
#  -6.24856770e+00  9.25995273e-02 -2.51042881e+00 -3.13964450e-05
#   6.90475382e-04  1.44122013e-01  1.97108559e-01 -1.59436578e+00]

# %%
# %%time
#To get predicted values for the input values
#print(f"predicted response:\n{results.fittedvalues}")
Bulb_pred = results.predict(x)
print(f"predicted response:\n{results.predict(x)}")
# Out:
# predicted response:
# [17.68704592 17.73143918 17.60817444 17.2049376  17.40150818 17.581895
#  17.72781909 18.62801828 18.94964881 18.81114215 19.01991077 18.81130784
#  17.46168706 17.67145082 17.9815891  18.23626013 18.53191901 19.00699146
#  18.79722494 18.39632146 18.92725329 18.9161039  18.6561437  18.86297894
#  18.66926685 18.9405365  18.94828176 18.68752967 19.30439362 19.74021784
#  19.43730805 19.44055547 19.40406658 19.17654627 19.4592551  19.43197628
#  20.02363701 20.00296741 20.23987584 20.4533322  20.17057261 20.21707886
#  20.54333312 20.48996533 19.96099429 20.16192292 20.21843248 20.26235852
#  20.41863856 20.58806185 20.49927266 21.0708611  20.53639386 20.28785423
#  20.54168862 20.48509965 20.8255653  20.98139315 21.51178504 21.47860643
#  21.68485808 21.90960264 22.42215656 22.32770909 22.29997157 22.33233116
#  22.03748803 22.0769117  21.9178321  21.99911766 22.53845896 22.25260729
#  22.67230057 22.49258515 22.57647928 22.37908562 22.81162571 22.77440336
#  23.46268742 23.83584462 24.5351038  24.79601707 25.22327505 25.52195645
#  25.64777156 25.58908601 26.12300976 26.28718546 26.61326302 26.97869293
#  27.20218627]
# Wall time: 1 ms

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(1, 92, 1)
#y = 
z = Bulb_pred
plt.plot(x, y)
plt.plot(x, z, color='pink', label='predicted Diameters')
plt.plot(x, y, color='y', label='True Diameters')
plt.ylabel('Diameter of Bulb(mm)', fontsize=14)
plt.xlabel('Days after Transplant', fontsize=14)

plt.title('Onion Bulb Diameter Predictions', fontsize=18)
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# !pip install rfpimp
# Out:
# Requirement already satisfied: rfpimp in c:\users\igone\anaconda3\lib\site-packages (1.3.7)
# Requirement already satisfied: scikit-learn in c:\users\igone\anaconda3\lib\site-packages (from rfpimp) (0.24.2)
# Requirement already satisfied: pandas in c:\users\igone\anaconda3\lib\site-packages (from rfpimp) (1.3.4)
# Requirement already satisfied: numpy in c:\users\igone\anaconda3\lib\site-packages (from rfpimp) (1.20.3)
# Requirement already satisfied: matplotlib in c:\users\igone\anaconda3\lib\site-packages (from rfpimp) (3.4.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\igone\anaconda3\lib\site-packages (from matplotlib->rfpimp) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\igone\anaconda3\lib\site-packages (from matplotlib->rfpimp) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\igone\anaconda3\lib\site-packages (from matplotlib->rfpimp) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\igone\anaconda3\lib\site-packages (from matplotlib->rfpimp) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\igone\anaconda3\lib\site-packages (from matplotlib->rfpimp) (1.3.1)
# Requirement already satisfied: six in c:\users\igone\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib->rfpimp) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\igone\anaconda3\lib\site-packages (from pandas->rfpimp) (2021.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\igone\anaconda3\lib\site-packages (from scikit-learn->rfpimp) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\igone\anaconda3\lib\site-packages (from scikit-learn->rfpimp) (1.1.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\igone\anaconda3\lib\site-packages (from scikit-learn->rfpimp) (1.7.1)

# %%
import rfpimp
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

######################################## Data preparation #########################################

#file = 'https://aegis4048.github.io/downloads/notebooks/sample_data/unconv_MV_v5.csv'
#df = pd.read_csv(file)
features = ['DAT(days)','Temp','WC','NL','N(PTC) (mg/g)','P(PTC) (mg/g)','K(PTC) (mg/g)','Ca(PTC) (mg/g)','Mg(PTC) (mg/g)','S(PTC) (mg/g)','Na(PTC) (mg/g)','Diameter of Bulb(mm)']

######################################## Train/test split #########################################

df_train, df_test = train_test_split(df, test_size=0.20)
df_train = df_train[features]
df_test = df_test[features]

X_train, y_train = df_train.drop('Diameter of Bulb(mm)',axis=1), df_train['Diameter of Bulb(mm)']
X_test, y_test = df_test.drop('Diameter of Bulb(mm)',axis=1), df_test['Diameter of Bulb(mm)']

################################################ Train #############################################

rf = RandomForestRegressor(n_estimators=100, n_jobs=-1)
rf.fit(X_train, y_train)

############################### Permutation feature importance #####################################

imp = rfpimp.importances(rf, X_test, y_test)

############################################## Plot ################################################

fig, ax = plt.subplots(figsize=(6, 3))

ax.barh(imp.index, imp['Importance'], height=0.8, facecolor='yellow', alpha=0.8, edgecolor='k')
ax.set_xlabel('Importance score')
ax.set_title('Permutation feature importance')
ax.text(0.8, 0.15, 'NFT', fontsize=12, ha='center', va='center',
        transform=ax.transAxes, color='grey', alpha=0.5)
plt.gca().invert_yaxis()

fig.tight_layout()
